# %%
# !git config--global user.name "YanaMinyaylo"
# !git config--global user.email "minyailo_yana@mail.ru"
# !git config--global user "Rm070997"
# Out:
# git: 'config--global' is not a git command. See 'git --help'.
# git: 'config--global' is not a git command. See 'git --help'.
# git: 'config--global' is not a git command. See 'git --help'.

# %%
token = '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'
username = 'YanaMinyaylo'
repo = 'NS'

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'NS'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 57 (delta 30), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (57/57), done.

# %%
# %cd {repo}
# Out:
# /content/NS

# %%
# %ls
# Out:
#  NS_data.csv                Syncro_ICS_imu_3.ipynb       Y1_imu1.csv
#  Syncro_ICS_imu_200.ipynb   Syncro_ICS_imu.ipynb         Y1_imu2.csv
# 'Syncro_ICS_imu(2).ipynb'   Y1_2022_09_15_20_43_03.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import interpolate
from scipy import signal
from scipy.ndimage import gaussian_filter

# %%
directory = '/content/NS/NS_data.csv'

# %%
df = pd.read_csv(directory)

# %%
X = df['gx']
y = df['Hor_eye']

# %%
X = np.array(X).reshape(-1, 1)
y = np.array(y).reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
n1 = 0
n2 = 20000
n3 = -1
scaler = StandardScaler()
x_train = scaler.fit_transform(X[n1:n2])
y_train = scaler.fit_transform(y[n1:n2])
x_test = scaler.fit_transform(X[n2:n3])
y_test = scaler.fit_transform(y[n2:n3])

# %%
features_set = []
labels = []

n = 80
k = 1

for i in range(n, len(x_train)):
    features_set.append(x_train[i-n:i, 0])
    labels.append(y_train[i-k:i, 0])

features_set_test = []
labels_test = []

for i in range(n, len(x_test)):
    features_set_test.append(x_test[i-n:i, 0])
    labels_test.append(y_test[i-k:i, 0])

features_set, labels = np.array(features_set), np.array(labels)
features_set_test, labels_test = np.array(features_set_test), np.array(labels_test)

print(features_set.shape, labels.shape)
print(features_set_test.shape, labels_test.shape)
# Out:
# (19920, 80) (19920, 1)
# (13670, 80) (13670, 1)

# %%
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))
labels = np.reshape(labels, (labels.shape[0], labels.shape[1], 1))

features_set_test = np.reshape(features_set_test, (features_set_test.shape[0], features_set_test.shape[1], 1))
labels_test = np.reshape(labels_test, (labels_test.shape[0], labels_test.shape[1], 1))

print(features_set.shape, labels.shape)
print(features_set_test.shape, labels_test.shape)
# Out:
# (19920, 80, 1) (19920, 1, 1)
# (13670, 80, 1) (13670, 1, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
u = 50
model_MSE = Sequential()
model_MSE.add(LSTM(units= u, return_sequences=True, input_shape=(features_set.shape[1], 1)))
model_MSE.add(Dropout(0.2))

model_MSE.add(LSTM(units=u))
model_MSE.add(Dropout(0.2))

model_MSE.add(Dense(units = labels.shape[1]))

model_MSE.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
result_MSE = model_MSE.fit(features_set, labels, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 623/623 [==============================] - 14s 9ms/step - loss: 0.8873
# Epoch 2/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.8774
# Epoch 3/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.8702
# Epoch 4/100
# 623/623 [==============================] - 7s 12ms/step - loss: 0.8538
# Epoch 5/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.8401
# Epoch 6/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.8189
# Epoch 7/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.8012
# Epoch 8/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.8407
# Epoch 9/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.8042
# Epoch 10/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.8021
# Epoch 11/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.7710
# Epoch 12/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.7536
# Epoch 13/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.7491
# Epoch 14/100
# 623/623 [==============================] - 5s 9ms/step - loss: 0.7346
# Epoch 15/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.7379
# Epoch 16/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.7289
# Epoch 17/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.7235
# Epoch 18/100
# 623/623 [==============================] - 9s 14ms/step - loss: 0.7148
# Epoch 19/100
# 623/623 [==============================] - 7s 12ms/step - loss: 0.7167
# Epoch 20/100
# 623/623 [==============================] - 8s 13ms/step - loss: 0.6987
# Epoch 21/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.7089
# Epoch 22/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.7001
# Epoch 23/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.6923
# Epoch 24/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6838
# Epoch 25/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6833
# Epoch 26/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.7280
# Epoch 27/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6862
# Epoch 28/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.7464
# Epoch 29/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6748
# Epoch 30/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6780
# Epoch 31/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6792
# Epoch 32/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.6705
# Epoch 33/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.6622
# Epoch 34/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6476
# Epoch 35/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6572
# Epoch 36/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6355
# Epoch 37/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6444
# Epoch 38/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6290
# Epoch 39/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6216
# Epoch 40/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6002
# Epoch 41/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5922
# Epoch 42/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6094
# Epoch 43/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6238
# Epoch 44/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6042
# Epoch 45/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6149
# Epoch 46/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.6001
# Epoch 47/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5906
# Epoch 48/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5736
# Epoch 49/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5759
# Epoch 50/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5589
# Epoch 51/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5554
# Epoch 52/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5481
# Epoch 53/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5406
# Epoch 54/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5335
# Epoch 55/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5483
# Epoch 56/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5385
# Epoch 57/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.5299
# Epoch 58/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5161
# Epoch 59/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5281
# Epoch 60/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5059
# Epoch 61/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5129
# Epoch 62/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4988
# Epoch 63/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5053
# Epoch 64/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4889
# Epoch 65/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5053
# Epoch 66/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.5429
# Epoch 67/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5219
# Epoch 68/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5113
# Epoch 69/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4851
# Epoch 70/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.5015
# Epoch 71/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4836
# Epoch 72/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4654
# Epoch 73/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4544
# Epoch 74/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4740
# Epoch 75/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4406
# Epoch 76/100
# 623/623 [==============================] - 5s 9ms/step - loss: 0.4369
# Epoch 77/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.4314
# Epoch 78/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4454
# Epoch 79/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4175
# Epoch 80/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4246
# Epoch 81/100
# 623/623 [==============================] - 8s 13ms/step - loss: 0.4178
# Epoch 82/100
# 623/623 [==============================] - 9s 15ms/step - loss: 0.4209
# Epoch 83/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.4020
# Epoch 84/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4081
# Epoch 85/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3990
# Epoch 86/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3938
# Epoch 87/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3695
# Epoch 88/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4149
# Epoch 89/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4155
# Epoch 90/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3924
# Epoch 91/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4029
# Epoch 92/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3867
# Epoch 93/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3612
# Epoch 94/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.3698
# Epoch 95/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3474
# Epoch 96/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3575
# Epoch 97/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3543
# Epoch 98/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3553
# Epoch 99/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3422
# Epoch 100/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3337

# %%
loss_history = np.array(result_MSE.history['loss'])

# %%
result_MSE_2 = model_MSE.fit(features_set, labels, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 623/623 [==============================] - 5s 9ms/step - loss: 0.3390
# Epoch 2/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3410
# Epoch 3/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3237
# Epoch 4/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3109
# Epoch 5/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3128
# Epoch 6/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3283
# Epoch 7/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3028
# Epoch 8/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3057
# Epoch 9/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3052
# Epoch 10/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3040
# Epoch 11/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3112
# Epoch 12/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.3111
# Epoch 13/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3229
# Epoch 14/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3086
# Epoch 15/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2781
# Epoch 16/100
# 623/623 [==============================] - 12s 19ms/step - loss: 0.3131
# Epoch 17/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.3099
# Epoch 18/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.2844
# Epoch 19/100
# 623/623 [==============================] - 8s 13ms/step - loss: 0.2658
# Epoch 20/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.2953
# Epoch 21/100
# 623/623 [==============================] - 8s 13ms/step - loss: 0.3090
# Epoch 22/100
# 623/623 [==============================] - 9s 15ms/step - loss: 0.2734
# Epoch 23/100
# 623/623 [==============================] - 7s 12ms/step - loss: 0.2793
# Epoch 24/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2655
# Epoch 25/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2806
# Epoch 26/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2499
# Epoch 27/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2937
# Epoch 28/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.2532
# Epoch 29/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2700
# Epoch 30/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.2428
# Epoch 31/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.2882
# Epoch 32/100
# 623/623 [==============================] - 6s 10ms/step - loss: 0.2612
# Epoch 33/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2391
# Epoch 34/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.2611
# Epoch 35/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2445
# Epoch 36/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2642
# Epoch 37/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2356
# Epoch 38/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2434
# Epoch 39/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2382
# Epoch 40/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2265
# Epoch 41/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.2302
# Epoch 42/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2303
# Epoch 43/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2392
# Epoch 44/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2699
# Epoch 45/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2326
# Epoch 46/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2103
# Epoch 47/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2231
# Epoch 48/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2136
# Epoch 49/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.1970
# Epoch 50/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.2455
# Epoch 51/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2288
# Epoch 52/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2217
# Epoch 53/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.2169
# Epoch 54/100
# 623/623 [==============================] - 7s 11ms/step - loss: 0.2202
# Epoch 55/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2304
# Epoch 56/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2109
# Epoch 57/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.1757
# Epoch 58/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2218
# Epoch 59/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.1892
# Epoch 60/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.1749
# Epoch 61/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.1854
# Epoch 62/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2024
# Epoch 63/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.1853
# Epoch 64/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.1839
# Epoch 65/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.1804
# Epoch 66/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3578
# Epoch 67/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4240
# Epoch 68/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4425
# Epoch 69/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4477
# Epoch 70/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.4392
# Epoch 71/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3813
# Epoch 72/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3806
# Epoch 73/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3445
# Epoch 74/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3431
# Epoch 75/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3317
# Epoch 76/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3322
# Epoch 77/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3189
# Epoch 78/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3042
# Epoch 79/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2974
# Epoch 80/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2923
# Epoch 81/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2932
# Epoch 82/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2570
# Epoch 83/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.3031
# Epoch 84/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2594
# Epoch 85/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2328
# Epoch 86/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2521
# Epoch 87/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2516
# Epoch 88/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.2244
# Epoch 89/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2243
# Epoch 90/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2323
# Epoch 91/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2308
# Epoch 92/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2235
# Epoch 93/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2434
# Epoch 94/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2138
# Epoch 95/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2718
# Epoch 96/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2730
# Epoch 97/100
# 623/623 [==============================] - 6s 9ms/step - loss: 0.2252
# Epoch 98/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2226
# Epoch 99/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2241
# Epoch 100/100
# 623/623 [==============================] - 5s 8ms/step - loss: 0.2207

# %%
loss_history2 = np.array(result_MSE_2.history['loss'])

# %%
loss = np.hstack((loss_history, loss_history2))

# %%
plt.figure(figsize=(15,10))
plt.plot(np.arange(1, len(loss)+1), loss, color = 'blue', label = 'MSE loss')
plt.title('Training loss',  fontsize=18)
plt.xlabel('Epoch',  fontsize=15)
plt.ylabel('Loss',  fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
predictions_MSE = model_MSE.predict(features_set_test)
predictions_MSE = scaler.inverse_transform(predictions_MSE)

# %%
fig, ax = plt.subplots(ncols=1, nrows = 3, figsize=(30, 15))
n1 = 0
n2 = 1000
n3 = 2000
n4 = 3000


ax[0].plot(y_test[n1:n2], color='blue', label='real eye movement')
ax[0].plot(predictions_MSE[n1:n2], color='red', label='Predicted eye movement (MsE)')

ax[1].plot(y_test[n2:n3], color='blue', label='real eye movement')
ax[1].plot(predictions_MSE[n2:n3], color='red', label='Predicted eye movement (MSE)')

ax[2].plot(y_test[n3:n4], color='blue', label='real eye movement')
ax[2].plot(predictions_MSE[n3:n4], color='red', label='Predicted eye movement (MsE)')

# plt.title('Oculogram', fontsize = 20)
plt.xlabel('time', fontsize=18)
plt.ylabel('horizontal position', fontsize=18)

ax[0].legend(fontsize=15)
ax[1].legend(fontsize=15)
ax[2].legend(fontsize=15)


plt.show()
